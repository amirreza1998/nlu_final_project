# %% [markdown]
# https://github.com/copilot/share/ca601336-4ac0-8877-b113-e20380c449a8

# %% [markdown]
# #Writing to a JSONL file

# %%
import json

data = [
    {"query": "برای افسردگی‌ام نیاز به مشاور دارم و می‌خواهم بدانم هزینه جلسات چقدر است.", "intents":["seek_coping_strategy", "inquire_cost"]},
    {"query": "علت تب و لرز در کودکان چیست؟", "intents": ["ask_symptom_cause"]},
    {"query": "فردا هوا بارانی است؟", "intents": ["out_of_scope"]},
    {"query": "من برای اضطرابم نیاز به کمک دارم و می‌خواهم در مورد داروی سرترالین اطلاعات بگیرم.", "intents":  ["seek_coping_strategy", "medication_inquiry"]},
    {"query": "علت سردرد و حالت تهوع چیست؟", "intents": ["ask_symptom_cause"] },
    {"query": "چطور با استرس امتحان کنار بیام؟", "intents": ["seek_coping_strategy"] },
    {"query": "می‌خوام برای هفته آینده یک وقت دکتر پوست بگیرم و هزینه ویزیت چقدره؟", "intents": ["schedule_appointment", "inquire_cost"] },
    {"query": "برای افسردگی‌ام نیاز به کمک دارم و می‌خواستم در مورد داروی سرترالین هم بپرسم.", "intents": ["seek_coping_strategy", "medication_inquiry"] },
    {"query": "بهترین رستوران تهران کجاست؟", "intents": ["out_of_scope"] }
]

with open("data.jsonl", "w", encoding="utf-8") as f:
    for item in data:
        f.write(json.dumps(item, ensure_ascii=False) + "\n")

# %% [markdown]
# # Reading from a JSONL file

# %%
import json

data = []
with open("data.jsonl", "r", encoding="utf-8") as f:
    for line in f:
        item = json.loads(line)
        data.append(item)
print(len(data))
# Now `data` is a list of dictionaries

# %%
# !pip install datasets

# %% [markdown]
# # set token

# %%
use_auth_token="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"

# %% [markdown]
# # load dataset customer_service_intent_detection

# %%
from huggingface_hub import hf_hub_download
import pandas as pd

csv_path = hf_hub_download(
    repo_id="jonathansuru/customer_service_intent_detection",
    filename="detection.csv",
    repo_type="dataset",
    use_auth_token=use_auth_token
)

df = pd.read_csv(csv_path)
# Out:
# detection.csv: 0.00B [00:00, ?B/s]

# %%
repr(df.columns)
# print(df["completion"][4])
[print(item) for item in df["completion"][:300]]
# Out:
#  switch account END
#  place order END
#  cancel order END
#  contact customer service END
#  switch account END
#  change order END
#  delivery options END
#  delivery period END
#  delivery period END
#  check payment methods END
#  track order END
#  delivery options END
#  delete account END
#  delivery options END
#  place order END
#  payment issue END
#  edit account END
#  change order END
#  recover password END
#  newsletter subscription END
#  contact human agent END
#  delivery period END
#  newsletter subscription END
#  contact human agent END
#  set up shipping address END
#  registration problems END
#  switch account END
#  place order END
#  check cancellation fee END
#  check invoice END
#  delivery options END
#  contact customer service END
#  contact customer service END
#  contact customer service END
#  delivery period END
#  newsletter subscription END
#  edit account END
#  delete account END
#  payment issue END
#  place order END
#  review END
# ...

# %%
import pandas as pd
import json
import re

# Example DataFrame
# df = pd.read_csv("your_file.csv")

def extract_query(prompt):
    # Extract after 'sentence: ' and before first actual newline
    match = re.search(r'Customer:\s*(.*)', prompt)
    if match:
        # print(match.group(1).strip())
        return match.group(1).strip()
    return None

def extract_intents(completion):
    # Extract the string after 'intents:' and before the next comma or newline
    match = completion.replace("END", "").strip()
    return match
with open('output.jsonl', 'w', encoding='utf8') as f:
    for idx, row in df.iterrows():
        # print(row)
        query = extract_query(row['prompt'])
        intents = extract_intents(row['completion'])
        if query is not None:
            # print("hi")
            obj = {"query": query, "intents": intents}
            f.write(json.dumps(obj, ensure_ascii=False) + '\n')

# %%
# import re
# def extract_query(prompt):
#     # Extract after 'sentence: ' and before first actual newline
#     match = re.search(r'sentence:\s*(.*?)(?:\n|$)', prompt)
#     if match:
#         return match.group(1).strip()
#     return None

# # Test it
id = 10
print(df['prompt'][id])
print("Extracted query:", extract_query(df['prompt'][id]))
print("Extracted query:", extract_intents(df['completion'][id]))
# Out:
# Please categorise the customer intent from the conversation below:
#
# ###
#
# Customer: how to see the ETA of the purchase 732201349959?
# The intention is as follows:
# Extracted query: how to see the ETA of the purchase 732201349959?
# Extracted query: track order

# %%
unique_results_list = df['completion'].unique().tolist()
unique_results_list_cleaned = [item.replace("END", "").strip() for item in unique_results_list]
# print(unique_results_list_cleaned)
print("list of clean up intent:")
[print(item) for item in unique_results_list_cleaned if item!=None]
# Out:
# list of clean up intent:
# switch account
# place order
# cancel order
# contact customer service
# change order
# delivery options
# delivery period
# check payment methods
# track order
# delete account
# payment issue
# edit account
# recover password
# newsletter subscription
# contact human agent
# set up shipping address
# registration problems
# check cancellation fee
# check invoice
# review
# create account
# change shipping address
# get refund
# track refund
# check refund policy
# complaint
# get invoice
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
import json

data = []
with open("output.jsonl", "r", encoding="utf-8") as f:
    for line in f:
        # print(line)
        item = json.loads(line)
        data.append(item)
print(len(data))
# Now `data` is a list of dictionaries
# Out:
# 1944

# %% [markdown]
# ##concate with self compiled model

# %%
import pandas as pd

# Load the custom data from the JSONL file
with open('data.jsonl', 'r', encoding='utf-8') as f:
    custom_data = [json.loads(line) for line in f]

# Convert the custom data to a pandas DataFrame
custom_df = pd.DataFrame(custom_data)

# Rename columns in custom_df to match df
custom_df = custom_df.rename(columns={'query': 'prompt', 'intents': 'completion'})


# Combine the two DataFrames
combined_df = pd.concat([df, custom_df], ignore_index=True)

# Display the first few rows of the combined DataFrame
display(combined_df.head())
# Out:
#                                               prompt  \
# 0  Please categorise the customer intent from the...
# 1  Please categorise the customer intent from the...
# 2  Please categorise the customer intent from the...
# 3  Please categorise the customer intent from the...
# 4  Please categorise the customer intent from the...
#
#                       completion
# 0             switch account END
# 1                place order END
# 2               cancel order END
# 3   contact customer service END
# 4             switch account END

# %% [markdown]
# Now that the datasets are combined, the next step is to format the data into a conversational format. This is a crucial step to ensure the model can learn from the data effectively. We will create a new column called "text" that will contain the formatted conversational data.

# %% [markdown]
# # convert to the proper data input

# %%
def convert_to_aya_format(input_file, output_file):
    with open(input_file, 'r', encoding='utf-8') as f_in, \
         open(output_file, 'w', encoding='utf-8') as f_out:

        for line in f_in:
            if line.strip():
                row = json.loads(line.strip())

                # Aya-compatible format
                conversation = [
                    {"role": "user", "content": row['query']},
                    {"role": "assistant", "content": ', '.join(row['intents'])}
                ]

                training_example = {"messages": conversation}
                f_out.write(json.dumps(training_example, ensure_ascii=False) + '\n')

# Convert for Aya
convert_to_aya_format('output.jsonl', 'aya_training_data.jsonl')

# %% [markdown]
# Now that the data is in the correct conversational format, the next step is to tokenize it. This will convert the text into a sequence of numbers that the model can process.

# %% [markdown]
# # load model

# %%
import transformers
import torch

model_id = "CohereLabs/aya-23-8B"

pipeline = transformers.pipeline(
    "text-generation",
    model=model_id,
    model_kwargs={"torch_dtype": torch.bfloat16},
    device_map="auto",
    token = use_auth_token
)

messages = [
    {"role": "system", "content": "You are a pirate chatbot who always responds in pirate speak!"},
    {"role": "user", "content": "Who are you?"},
]

outputs = pipeline(
    messages,
    max_new_tokens=256,
)
print(outputs[0]["generated_text"][-1])
# Out:
# config.json:   0%|          | 0.00/640 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/21.0k [00:00<?, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# ...

# %% [markdown]
# # Setup Training Environment

# %%
import torch
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    TrainingArguments,
    Trainer,
    DataCollatorForLanguageModeling
)
from datasets import load_dataset
from peft import LoraConfig, get_peft_model, TaskType
import wandb

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Model selection - choose based on your GPU memory
model_options = {
    "small": "CohereForAI/aya-23-8B",      # ~16GB VRAM needed
    "medium": "CohereForAI/aya-101",        # ~32GB VRAM needed
}

model_name = model_options["small"]  # Change if you have more VRAM
print(f"Using model: {model_name}")
# Out:
# Using device: cuda
# Using model: CohereForAI/aya-23-8B

# %% [markdown]
# # Load and Prepare Model

# %%
# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    device_map="auto",
    trust_remote_code=True,
    attn_implementation="flash_attention_2" if torch.cuda.is_available() else None
)

# Add padding token if missing
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
    tokenizer.pad_token_id = tokenizer.eos_token_id

# Configure LoRA for efficient fine-tuning
lora_config = LoraConfig(
    task_type=TaskType.CAUSAL_LM,
    inference_mode=False,
    r=16,
    lora_alpha=32,
    lora_dropout=0.1,
    target_modules=["q_proj", "v_proj", "k_proj", "o_proj", "gate_proj", "up_proj", "down_proj"]
)

# Apply LoRA
model = get_peft_model(model, lora_config)
model.print_trainable_parameters()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     408     try:
# --> 409         response.raise_for_status()
#     410     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/CohereForAI/aya-23-8B/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# ...
